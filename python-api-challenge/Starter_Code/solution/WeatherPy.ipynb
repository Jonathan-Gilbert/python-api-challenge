# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = f"https://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | west island
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | bairnsdale
# Processing Record 8 of Set 1 | port isabel
# Processing Record 9 of Set 1 | blackmans bay
# Processing Record 10 of Set 1 | cedar city
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | naracoorte
# Processing Record 13 of Set 1 | olonkinbyen
# Processing Record 14 of Set 1 | emkhomazi
# Processing Record 15 of Set 1 | strezhevoy
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | lenoir
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | lensk
# Processing Record 20 of Set 1 | afaahiti
# Processing Record 21 of Set 1 | bathsheba
# Processing Record 22 of Set 1 | bardaskan
# City not found. Skipping...
# Processing Record 23 of Set 1 | kalmunai
# Processing Record 24 of Set 1 | waitangi
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | anadyr
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | igarka
# Processing Record 29 of Set 1 | chiras
# Processing Record 30 of Set 1 | sann
# Processing Record 31 of Set 1 | invercargill
# Processing Record 32 of Set 1 | adamstown
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | ketchikan
# Processing Record 35 of Set 1 | shingu
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | vorgashor
# Processing Record 38 of Set 1 | tura
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | isafjordur
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | choyr
# Processing Record 46 of Set 1 | melfi
# Processing Record 47 of Set 1 | hamilton
# Processing Record 48 of Set 1 | tindouf
# Processing Record 49 of Set 1 | extrema
# Processing Record 50 of Set 1 | badger
# Processing Record 0 of Set 2 | port elizabeth
# Processing Record 1 of Set 2 | santa terezinha
# Processing Record 2 of Set 2 | grytviken
# Processing Record 3 of Set 2 | new plymouth
# Processing Record 4 of Set 2 | imperatriz
# Processing Record 5 of Set 2 | turbat
# Processing Record 6 of Set 2 | edinburgh of the seven seas
# Processing Record 7 of Set 2 | ola
# Processing Record 8 of Set 2 | tazacorte
# Processing Record 9 of Set 2 | odienne
# Processing Record 10 of Set 2 | zeya
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | fort st. john
# Processing Record 13 of Set 2 | vilyuchinsk
# Processing Record 14 of Set 2 | shimoda
# Processing Record 15 of Set 2 | toliara
# Processing Record 16 of Set 2 | champerico
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | barra dos coqueiros
# Processing Record 19 of Set 2 | kralendijk
# Processing Record 20 of Set 2 | arteche
# Processing Record 21 of Set 2 | krasnyy chikoy
# Processing Record 22 of Set 2 | bubaque
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | oualidia
# City not found. Skipping...
# Processing Record 25 of Set 2 | hermantown
# Processing Record 26 of Set 2 | charters towers
# Processing Record 27 of Set 2 | kourou
# Processing Record 28 of Set 2 | fallsburg
# Processing Record 29 of Set 2 | howrah
# Processing Record 30 of Set 2 | ostersund
# Processing Record 31 of Set 2 | alice springs
# Processing Record 32 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 33 of Set 2 | pechora
# Processing Record 34 of Set 2 | nadym
# Processing Record 35 of Set 2 | st. john's
# Processing Record 36 of Set 2 | muang phon-hong
# Processing Record 37 of Set 2 | badagry
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | port mathurin
# Processing Record 40 of Set 2 | ushuaia
# Processing Record 41 of Set 2 | xai-xai
# Processing Record 42 of Set 2 | benghazi
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | kunashak
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | codajas
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | margaret river
# Processing Record 0 of Set 3 | constantia
# Processing Record 1 of Set 3 | kayangel
# Processing Record 2 of Set 3 | bayan
# Processing Record 3 of Set 3 | bonthe
# Processing Record 4 of Set 3 | port shepstone
# Processing Record 5 of Set 3 | berdigestyakh
# Processing Record 6 of Set 3 | stanley
# Processing Record 7 of Set 3 | amos
# Processing Record 8 of Set 3 | borogontsy
# Processing Record 9 of Set 3 | kalamata
# Processing Record 10 of Set 3 | colonia
# Processing Record 11 of Set 3 | sao vicente
# Processing Record 12 of Set 3 | papatowai
# Processing Record 13 of Set 3 | udachny
# Processing Record 14 of Set 3 | tianpeng
# Processing Record 15 of Set 3 | salinopolis
# Processing Record 16 of Set 3 | egilsstadir
# Processing Record 17 of Set 3 | hassi messaoud
# Processing Record 18 of Set 3 | non thai
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | parkes
# Processing Record 21 of Set 3 | xiaoweizhai
# Processing Record 22 of Set 3 | puerto baquerizo moreno
# Processing Record 23 of Set 3 | devinuwara
# City not found. Skipping...
# Processing Record 24 of Set 3 | lashio
# Processing Record 25 of Set 3 | vilyuysk
# Processing Record 26 of Set 3 | fengcheng
# Processing Record 27 of Set 3 | morehead city
# Processing Record 28 of Set 3 | portland
# Processing Record 29 of Set 3 | dodge city
# Processing Record 30 of Set 3 | mil'kovo
# Processing Record 31 of Set 3 | khandyga
# Processing Record 32 of Set 3 | carmaux
# Processing Record 33 of Set 3 | klyuchi
# Processing Record 34 of Set 3 | xapuri
# Processing Record 35 of Set 3 | necochea
# Processing Record 36 of Set 3 | talnakh
# Processing Record 37 of Set 3 | marica
# Processing Record 38 of Set 3 | punta arenas
# Processing Record 39 of Set 3 | crane
# Processing Record 40 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 3 | ingeniero jacobacci
# Processing Record 42 of Set 3 | basco
# Processing Record 43 of Set 3 | al 'amarah
# Processing Record 44 of Set 3 | nuevitas
# Processing Record 45 of Set 3 | meadow lakes
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | togur
# Processing Record 48 of Set 3 | nemuro
# Processing Record 49 of Set 3 | sassandra
# Processing Record 0 of Set 4 | sao joao da barra
# Processing Record 1 of Set 4 | sabha
# Processing Record 2 of Set 4 | barakani
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | hood river
# Processing Record 5 of Set 4 | nar'yan-mar
# Processing Record 6 of Set 4 | saksaul'skiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | laguna
# Processing Record 10 of Set 4 | horta
# Processing Record 11 of Set 4 | tralee
# Processing Record 12 of Set 4 | dudinka
# Processing Record 13 of Set 4 | camargo
# Processing Record 14 of Set 4 | shitanjing
# Processing Record 15 of Set 4 | arquitecto tomas romero pereira
# Processing Record 16 of Set 4 | khombole
# Processing Record 17 of Set 4 | posse
# Processing Record 18 of Set 4 | emerald
# Processing Record 19 of Set 4 | pilar
# Processing Record 20 of Set 4 | mangrol
# Processing Record 21 of Set 4 | severo-yeniseyskiy
# Processing Record 22 of Set 4 | ust-nera
# Processing Record 23 of Set 4 | cockburn town
# Processing Record 24 of Set 4 | yokadouma
# Processing Record 25 of Set 4 | raja
# Processing Record 26 of Set 4 | kyosai
# Processing Record 27 of Set 4 | bilibino
# Processing Record 28 of Set 4 | ulsteinvik
# Processing Record 29 of Set 4 | juneau
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | puerto san jose
# Processing Record 33 of Set 4 | geraldton
# Processing Record 34 of Set 4 | gobabis
# Processing Record 35 of Set 4 | linqiong
# Processing Record 36 of Set 4 | dul'durga
# Processing Record 37 of Set 4 | shache
# Processing Record 38 of Set 4 | al kharijah
# Processing Record 39 of Set 4 | ploudalmezeau
# Processing Record 40 of Set 4 | yaren
# Processing Record 41 of Set 4 | qaqortoq
# Processing Record 42 of Set 4 | kirakira
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | lompoc
# Processing Record 45 of Set 4 | correntina
# Processing Record 46 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 47 of Set 4 | juan griego
# Processing Record 48 of Set 4 | happy valley-goose bay
# Processing Record 49 of Set 4 | san pedro pochutla
# Processing Record 0 of Set 5 | phumi veal sre
# Processing Record 1 of Set 5 | kismayo
# Processing Record 2 of Set 5 | leiyang
# Processing Record 3 of Set 5 | tintafor
# Processing Record 4 of Set 5 | machico
# Processing Record 5 of Set 5 | kuqa
# Processing Record 6 of Set 5 | haiku-pauwela
# Processing Record 7 of Set 5 | polovinnoye
# Processing Record 8 of Set 5 | fortaleza
# Processing Record 9 of Set 5 | woolgoolga
# Processing Record 10 of Set 5 | wailua homesteads
# Processing Record 11 of Set 5 | el nido
# Processing Record 12 of Set 5 | ho
# City not found. Skipping...
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | whitehorse
# Processing Record 15 of Set 5 | polur
# Processing Record 16 of Set 5 | samana
# Processing Record 17 of Set 5 | alamos
# Processing Record 18 of Set 5 | pangody
# Processing Record 19 of Set 5 | lospalos
# Processing Record 20 of Set 5 | mana
# Processing Record 21 of Set 5 | utrik
# Processing Record 22 of Set 5 | bria
# Processing Record 23 of Set 5 | papayal
# Processing Record 24 of Set 5 | fale old settlement
# Processing Record 25 of Set 5 | yanchep
# Processing Record 26 of Set 5 | acapulco de juarez
# Processing Record 27 of Set 5 | dawson creek
# Processing Record 28 of Set 5 | mournies
# Processing Record 29 of Set 5 | aasiaat
# Processing Record 30 of Set 5 | kribi
# Processing Record 31 of Set 5 | tapes
# Processing Record 32 of Set 5 | letlhakeng
# Processing Record 33 of Set 5 | atafu village
# Processing Record 34 of Set 5 | tangalle
# Processing Record 35 of Set 5 | ocos
# Processing Record 36 of Set 5 | kailua-kona
# Processing Record 37 of Set 5 | lihue
# Processing Record 38 of Set 5 | tughyl
# Processing Record 39 of Set 5 | tazovsky
# Processing Record 40 of Set 5 | greymouth
# Processing Record 41 of Set 5 | faya-largeau
# Processing Record 42 of Set 5 | nuku'alofa
# Processing Record 43 of Set 5 | conde
# Processing Record 44 of Set 5 | hollidaysburg
# Processing Record 45 of Set 5 | montagu
# Processing Record 46 of Set 5 | sinabang
# Processing Record 47 of Set 5 | filadelfia
# Processing Record 48 of Set 5 | chonchi
# Processing Record 49 of Set 5 | tippi
# Processing Record 0 of Set 6 | highland
# Processing Record 1 of Set 6 | pakuranga
# Processing Record 2 of Set 6 | tasqala
# Processing Record 3 of Set 6 | taoudenni
# Processing Record 4 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 6 | undurkhaan
# Processing Record 6 of Set 6 | rundu
# Processing Record 7 of Set 6 | sandnessjoen
# Processing Record 8 of Set 6 | khandud
# Processing Record 9 of Set 6 | suva
# Processing Record 10 of Set 6 | nuuk
# Processing Record 11 of Set 6 | sakakah
# Processing Record 12 of Set 6 | archangelos
# Processing Record 13 of Set 6 | antanifotsy
# Processing Record 14 of Set 6 | nova sintra
# Processing Record 15 of Set 6 | shengli
# Processing Record 16 of Set 6 | coquimbo
# Processing Record 17 of Set 6 | san antonio de pale
# Processing Record 18 of Set 6 | ugoofaaru
# Processing Record 19 of Set 6 | bondo
# Processing Record 20 of Set 6 | sibiti
# Processing Record 21 of Set 6 | enewetak
# Processing Record 22 of Set 6 | atchison
# Processing Record 23 of Set 6 | ulladulla
# Processing Record 24 of Set 6 | mersin
# Processing Record 25 of Set 6 | san felipe
# Processing Record 26 of Set 6 | hailey
# Processing Record 27 of Set 6 | les cayes
# Processing Record 28 of Set 6 | mount pearl
# Processing Record 29 of Set 6 | yarmouth
# Processing Record 30 of Set 6 | nguigmi
# Processing Record 31 of Set 6 | cururupu
# Processing Record 32 of Set 6 | hawaiian paradise park
# Processing Record 33 of Set 6 | gniezno
# Processing Record 34 of Set 6 | prado
# Processing Record 35 of Set 6 | bandipura
# Processing Record 36 of Set 6 | churapcha
# Processing Record 37 of Set 6 | matoury
# Processing Record 38 of Set 6 | roxborough park
# Processing Record 39 of Set 6 | usinsk
# Processing Record 40 of Set 6 | praia da vitoria
# Processing Record 41 of Set 6 | martuk
# Processing Record 42 of Set 6 | eureka
# Processing Record 43 of Set 6 | brookings
# Processing Record 44 of Set 6 | hadibu
# Processing Record 45 of Set 6 | shinas
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | soran
# Processing Record 48 of Set 6 | escanaba
# Processing Record 49 of Set 6 | davutlar
# Processing Record 0 of Set 7 | poxoreo
# Processing Record 1 of Set 7 | boa vista
# Processing Record 2 of Set 7 | cidreira
# Processing Record 3 of Set 7 | burutu
# Processing Record 4 of Set 7 | baicheng
# Processing Record 5 of Set 7 | howard springs
# Processing Record 6 of Set 7 | kudahuvadhoo
# Processing Record 7 of Set 7 | belmonte
# Processing Record 8 of Set 7 | kamaishi
# Processing Record 9 of Set 7 | taro
# Processing Record 10 of Set 7 | mossel bay
# Processing Record 11 of Set 7 | i-n-salah
# Processing Record 12 of Set 7 | brisas de zicatela
# Processing Record 13 of Set 7 | namtsy
# Processing Record 14 of Set 7 | shalya
# Processing Record 15 of Set 7 | buka
# Processing Record 16 of Set 7 | korsakov
# Processing Record 17 of Set 7 | tanjung selor
# City not found. Skipping...
# Processing Record 18 of Set 7 | santa luzia
# Processing Record 19 of Set 7 | lazaro cardenas
# Processing Record 20 of Set 7 | uliastay
# Processing Record 21 of Set 7 | kingscliff
# Processing Record 22 of Set 7 | princeville
# Processing Record 23 of Set 7 | atamanovka
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | mount isa
# Processing Record 26 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 27 of Set 7 | dapa
# Processing Record 28 of Set 7 | verkhnevilyuysk
# Processing Record 29 of Set 7 | novohrad-volynskyi
# Processing Record 30 of Set 7 | yuzhno-kurilsk
# Processing Record 31 of Set 7 | saipan
# Processing Record 32 of Set 7 | casper
# Processing Record 33 of Set 7 | abeche
# Processing Record 34 of Set 7 | castillos
# Processing Record 35 of Set 7 | vernon
# Processing Record 36 of Set 7 | maneromango
# Processing Record 37 of Set 7 | ma'rib
# Processing Record 38 of Set 7 | kodinsk
# Processing Record 39 of Set 7 | papao
# Processing Record 40 of Set 7 | collinwood
# Processing Record 41 of Set 7 | la'ie
# Processing Record 42 of Set 7 | saint-philippe
# Processing Record 43 of Set 7 | mejit
# Processing Record 44 of Set 7 | creel
# Processing Record 45 of Set 7 | oltinko'l
# Processing Record 46 of Set 7 | adh dhibiyah
# City not found. Skipping...
# Processing Record 47 of Set 7 | prnjavor
# Processing Record 48 of Set 7 | rio grande
# Processing Record 49 of Set 7 | jieshi
# Processing Record 0 of Set 8 | san carlos
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | high rock
# Processing Record 3 of Set 8 | caruthersville
# Processing Record 4 of Set 8 | halfway
# Processing Record 5 of Set 8 | tanrake village
# City not found. Skipping...
# Processing Record 6 of Set 8 | conduaga
# Processing Record 7 of Set 8 | el calafate
# Processing Record 8 of Set 8 | itoman
# Processing Record 9 of Set 8 | axim
# Processing Record 10 of Set 8 | inarajan village
# Processing Record 11 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 12 of Set 8 | vila do maio
# Processing Record 13 of Set 8 | aden
# Processing Record 14 of Set 8 | puerto carreno
# Processing Record 15 of Set 8 | tobi village
# City not found. Skipping...
# Processing Record 16 of Set 8 | argostolion
# Processing Record 17 of Set 8 | goundam
# Processing Record 18 of Set 8 | sola
# Processing Record 19 of Set 8 | wick
# Processing Record 20 of Set 8 | swakopmund
# Processing Record 21 of Set 8 | dzilam gonzalez
# Processing Record 22 of Set 8 | al ghayzah
# Processing Record 23 of Set 8 | mutuipe
# Processing Record 24 of Set 8 | carahue
# Processing Record 25 of Set 8 | apodi
# Processing Record 26 of Set 8 | baran
# Processing Record 27 of Set 8 | lethem
# Processing Record 28 of Set 8 | mar del plata
# Processing Record 29 of Set 8 | puning
# Processing Record 30 of Set 8 | san miguel
# Processing Record 31 of Set 8 | ishigaki
# Processing Record 32 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 33 of Set 8 | bonny
# Processing Record 34 of Set 8 | port blair
# Processing Record 35 of Set 8 | qashyr
# Processing Record 36 of Set 8 | christchurch
# Processing Record 37 of Set 8 | rakops
# Processing Record 38 of Set 8 | nova vicosa
# Processing Record 39 of Set 8 | baluntaicun
# City not found. Skipping...
# Processing Record 40 of Set 8 | luderitz
# Processing Record 41 of Set 8 | saldanha
# Processing Record 42 of Set 8 | tallkalakh
# Processing Record 43 of Set 8 | calderitas
# Processing Record 44 of Set 8 | essaouira
# Processing Record 45 of Set 8 | jinchang
# Processing Record 46 of Set 8 | warman
# Processing Record 47 of Set 8 | lincoln
# Processing Record 48 of Set 8 | kibara
# Processing Record 49 of Set 8 | holualoa
# Processing Record 0 of Set 9 | pacasmayo
# Processing Record 1 of Set 9 | ulanhot
# Processing Record 2 of Set 9 | chapada dos guimaraes
# Processing Record 3 of Set 9 | kem'
# Processing Record 4 of Set 9 | machilipatnam
# Processing Record 5 of Set 9 | oranjemund
# Processing Record 6 of Set 9 | darwin
# Processing Record 7 of Set 9 | zalari
# Processing Record 8 of Set 9 | nogliki
# Processing Record 9 of Set 9 | kavaratti
# Processing Record 10 of Set 9 | sinop
# Processing Record 11 of Set 9 | guapore
# Processing Record 12 of Set 9 | ghormach
# Processing Record 13 of Set 9 | itaituba
# Processing Record 14 of Set 9 | sao francisco de paula
# Processing Record 15 of Set 9 | salta
# Processing Record 16 of Set 9 | lodja
# Processing Record 17 of Set 9 | beaufort west
# Processing Record 18 of Set 9 | bel ombre
# Processing Record 19 of Set 9 | huruta
# Processing Record 20 of Set 9 | yermolayevo
# Processing Record 21 of Set 9 | acarau
# Processing Record 22 of Set 9 | chernyshkovskiy
# Processing Record 23 of Set 9 | bengkulu
# Processing Record 24 of Set 9 | las tablas
# Processing Record 25 of Set 9 | bamboo flat
# Processing Record 26 of Set 9 | walvis bay
# Processing Record 27 of Set 9 | patnanungan
# Processing Record 28 of Set 9 | broken hill
# Processing Record 29 of Set 9 | solnechnogorsk
# Processing Record 30 of Set 9 | portmore
# Processing Record 31 of Set 9 | richards bay
# Processing Record 32 of Set 9 | dryden
# Processing Record 33 of Set 9 | padangsidempuan
# Processing Record 34 of Set 9 | fannuj
# City not found. Skipping...
# Processing Record 35 of Set 9 | colonia menno
# Processing Record 36 of Set 9 | haapsalu
# Processing Record 37 of Set 9 | kristiansund
# Processing Record 38 of Set 9 | untsukul'
# Processing Record 39 of Set 9 | fort mcmurray
# Processing Record 40 of Set 9 | la sarre
# Processing Record 41 of Set 9 | vakhsh
# Processing Record 42 of Set 9 | oriximina
# Processing Record 43 of Set 9 | rumbek
# Processing Record 44 of Set 9 | iskateley
# Processing Record 45 of Set 9 | maintirano
# Processing Record 46 of Set 9 | sitangkai
# Processing Record 47 of Set 9 | ulan bator
# Processing Record 48 of Set 9 | santiago del torno
# Processing Record 49 of Set 9 | guymon
# Processing Record 0 of Set 10 | weno
# Processing Record 1 of Set 10 | okhotsk
# Processing Record 2 of Set 10 | hirara
# Processing Record 3 of Set 10 | faratsiho
# Processing Record 4 of Set 10 | parabel'
# Processing Record 5 of Set 10 | auki
# Processing Record 6 of Set 10 | palikir - national government center
# Processing Record 7 of Set 10 | jiexiu
# Processing Record 8 of Set 10 | duncan town
# City not found. Skipping...
# Processing Record 9 of Set 10 | carolina beach
# Processing Record 10 of Set 10 | makokou
# Processing Record 11 of Set 10 | morondava
# Processing Record 12 of Set 10 | necocli
# Processing Record 13 of Set 10 | shalqar
# Processing Record 14 of Set 10 | krasnyye barrikady
# Processing Record 15 of Set 10 | kapustin yar
# Processing Record 16 of Set 10 | rosetta
# Processing Record 17 of Set 10 | alvaraes
# Processing Record 18 of Set 10 | fort bragg
# Processing Record 19 of Set 10 | saline
# Processing Record 20 of Set 10 | sur
# Processing Record 21 of Set 10 | westport
# Processing Record 22 of Set 10 | port saint john's
# Processing Record 23 of Set 10 | xining
# Processing Record 24 of Set 10 | pisco
# Processing Record 25 of Set 10 | pitimbu
# Processing Record 26 of Set 10 | south hedland
# Processing Record 27 of Set 10 | temiskaming shores
# Processing Record 28 of Set 10 | kangding
# Processing Record 29 of Set 10 | hobyo
# Processing Record 30 of Set 10 | tadine
# Processing Record 31 of Set 10 | salalah
# Processing Record 32 of Set 10 | atamaria
# City not found. Skipping...
# Processing Record 33 of Set 10 | ellsworth
# Processing Record 34 of Set 10 | korotchaevo
# City not found. Skipping...
# Processing Record 35 of Set 10 | arkhara
# Processing Record 36 of Set 10 | adrar
# Processing Record 37 of Set 10 | pemangkat
# Processing Record 38 of Set 10 | jhang sadr
# Processing Record 39 of Set 10 | funafuti
# Processing Record 40 of Set 10 | salina cruz
# Processing Record 41 of Set 10 | kone
# Processing Record 42 of Set 10 | nouadhibou
# Processing Record 43 of Set 10 | nizhnesortymskiy
# Processing Record 44 of Set 10 | uturoa
# Processing Record 45 of Set 10 | asosa
# Processing Record 46 of Set 10 | zayed city
# Processing Record 47 of Set 10 | preobrazheniye
# Processing Record 48 of Set 10 | ar raqqah
# Processing Record 49 of Set 10 | nongstoin
# Processing Record 0 of Set 11 | lata
# Processing Record 1 of Set 11 | newman
# Processing Record 2 of Set 11 | cabedelo
# Processing Record 3 of Set 11 | altai
# Processing Record 4 of Set 11 | illizi
# Processing Record 5 of Set 11 | linxia chengguanzhen
# Processing Record 6 of Set 11 | rasskazovo
# Processing Record 7 of Set 11 | whyalla stuart
# City not found. Skipping...
# Processing Record 8 of Set 11 | ciudad lazaro cardenas
# Processing Record 9 of Set 11 | kununurra
# Processing Record 10 of Set 11 | kerikeri
# Processing Record 11 of Set 11 | murghob
# Processing Record 12 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 13 of Set 11 | touros
# Processing Record 14 of Set 11 | nagqu
# Processing Record 15 of Set 11 | baardheere
# Processing Record 16 of Set 11 | broome
# Processing Record 17 of Set 11 | kataba
# Processing Record 18 of Set 11 | taroa
# Processing Record 19 of Set 11 | sisimiut
# Processing Record 20 of Set 11 | darhan
# Processing Record 21 of Set 11 | north bay
# Processing Record 22 of Set 11 | soroti
# Processing Record 23 of Set 11 | bhola
# Processing Record 24 of Set 11 | keflavik
# Processing Record 25 of Set 11 | qamdo
# Processing Record 26 of Set 11 | bourbon-lancy
# Processing Record 27 of Set 11 | tarfaya
# Processing Record 28 of Set 11 | petauke
# Processing Record 29 of Set 11 | sabang
# Processing Record 30 of Set 11 | shushtar
# Processing Record 31 of Set 11 | glace bay
# Processing Record 32 of Set 11 | whangarei
# Processing Record 33 of Set 11 | kutum
# Processing Record 34 of Set 11 | hami
# Processing Record 35 of Set 11 | hammerfest
# Processing Record 36 of Set 11 | florida
# Processing Record 37 of Set 11 | omuthiya
# City not found. Skipping...
# Processing Record 38 of Set 11 | senatobia
# Processing Record 39 of Set 11 | skiatook
# Processing Record 40 of Set 11 | padang
# Processing Record 41 of Set 11 | yeppoon
# Processing Record 42 of Set 11 | karachi
# Processing Record 43 of Set 11 | kavieng
# Processing Record 44 of Set 11 | placer
# Processing Record 45 of Set 11 | panaba
# Processing Record 46 of Set 11 | senanga
# Processing Record 47 of Set 11 | tual
# Processing Record 48 of Set 11 | san fernando
# Processing Record 49 of Set 11 | kill devil hills
# Processing Record 0 of Set 12 | la passe
# Processing Record 1 of Set 12 | puerto armuelles
# Processing Record 2 of Set 12 | oamaru
# Processing Record 3 of Set 12 | piti village
# Processing Record 4 of Set 12 | nema
# Processing Record 5 of Set 12 | sumbawa besar
# Processing Record 6 of Set 12 | mugia
# Processing Record 7 of Set 12 | rio san juan
# Processing Record 8 of Set 12 | tsimlyansk
# Processing Record 9 of Set 12 | springbok
# Processing Record 10 of Set 12 | pucon
# Processing Record 11 of Set 12 | paradsasvar
# Processing Record 12 of Set 12 | garhi khairo
# Processing Record 13 of Set 12 | at-bashi
# Processing Record 14 of Set 12 | laikit, laikit ii (dimembe)
# Processing Record 15 of Set 12 | minas de marcona
# Processing Record 16 of Set 12 | olenegorsk
# Processing Record 17 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 12 | zafar
# Processing Record 19 of Set 12 | mili
# Processing Record 20 of Set 12 | thurso
# Processing Record 21 of Set 12 | zhigalovo
# Processing Record 22 of Set 12 | biltine
# Processing Record 23 of Set 12 | northam
# Processing Record 24 of Set 12 | san matias
# Processing Record 25 of Set 12 | balabac
# Processing Record 26 of Set 12 | bogale
# Processing Record 27 of Set 12 | manta
# Processing Record 28 of Set 12 | bayanhongor
# Processing Record 29 of Set 12 | pariaman
# Processing Record 30 of Set 12 | new norfolk
# Processing Record 31 of Set 12 | siwa oasis
# Processing Record 32 of Set 12 | arkhangel'sk
# Processing Record 33 of Set 12 | bardai
# Processing Record 34 of Set 12 | nabire
# Processing Record 35 of Set 12 | tashtyp
# Processing Record 36 of Set 12 | sault ste. marie
# Processing Record 37 of Set 12 | mata-utu
# Processing Record 38 of Set 12 | dwarka
# Processing Record 39 of Set 12 | talakan
# Processing Record 40 of Set 12 | daru
# Processing Record 41 of Set 12 | sao jose da coroa grande
# Processing Record 42 of Set 12 | chinsali
# Processing Record 43 of Set 12 | buabidi
# City not found. Skipping...
# Processing Record 44 of Set 12 | ustyuzhna
# Processing Record 45 of Set 12 | selfoss
# Processing Record 46 of Set 12 | quezon
# Processing Record 47 of Set 12 | buzuluk
# Processing Record 48 of Set 12 | yuli
# Processing Record 49 of Set 12 | changyon
# Processing Record 0 of Set 13 | mankera
# Processing Record 1 of Set 13 | port-vila
# Processing Record 2 of Set 13 | makueni boma
# Processing Record 3 of Set 13 | gadzhiyevo
# Processing Record 4 of Set 13 | magong
# Processing Record 5 of Set 13 | vadso
# Processing Record 6 of Set 13 | safi
# Processing Record 7 of Set 13 | qarah zia' od din
# Processing Record 8 of Set 13 | metsemotlhaba
# Processing Record 9 of Set 13 | kuanda
# Processing Record 10 of Set 13 | hauterive
# Processing Record 11 of Set 13 | rukban
# City not found. Skipping...
# Processing Record 12 of Set 13 | remire-montjoly
# Processing Record 13 of Set 13 | chom bueng
# Processing Record 14 of Set 13 | sao martinho
# Processing Record 15 of Set 13 | tuburan
# Processing Record 16 of Set 13 | gbarnga
# Processing Record 17 of Set 13 | belozersk
# Processing Record 18 of Set 13 | oroqen zizhiqi
# Processing Record 19 of Set 13 | es castell
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          593
# Lat           593
# Lng           593
# Max Temp      593
# Humidity      593
# Cloudiness    593
# Wind Speed    593
# Country       593
# Date          593
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        west island -12.1568   96.8225     28.77        70          94
# 1     puerto natales -51.7236  -72.4875     12.11        74         100
# 2  port-aux-francais -49.3500   70.2167      8.66        96          99
# 3            college  64.8569 -147.8028    -14.00        50          75
# 4        yellowknife  62.4560 -114.3525    -23.66        84           0
#
#    Wind Speed Country        Date
# 0        8.27      CC  1709076724
# 1        4.25      CL  1709076725
# 2       11.19      TF  1709076726
# 3        1.54      US  1709076727
# 4        3.60      CA  1709076729

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              west island -12.1568   96.8225     28.77        70          94
# 1           puerto natales -51.7236  -72.4875     12.11        74         100
# 2        port-aux-francais -49.3500   70.2167      8.66        96          99
# 3                  college  64.8569 -147.8028    -14.00        50          75
# 4              yellowknife  62.4560 -114.3525    -23.66        84           0
#
#          Wind Speed Country        Date
# City_ID
# 0              8.27      CC  1709076724
# 1              4.25      CL  1709076725
# 2             11.19      TF  1709076726
# 3              1.54      US  1709076727
# 4              3.60      CA  1709076729

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Lat and Max Temp
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,260),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.7145976181108131

# %%
# Lat and Humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.10697450314277288

# %%
# Lat and Cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.09720657740488942

# %%
# Lat and Wind Speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,-0),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.06513917019996258

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3            college  64.8569 -147.8028    -14.00        50          75
# 4        yellowknife  62.4560 -114.3525    -23.66        84           0
# 7        port isabel  26.0734  -97.2086     28.02        69           0
# 9         cedar city  37.6775 -113.0619      7.54        29           0
# 12       olonkinbyen  70.9221   -8.7187     -1.91        97          99
#
#          Wind Speed Country        Date
# City_ID
# 3              1.54      US  1709076727
# 4              3.60      CA  1709076729
# 7              8.23      US  1709076732
# 9              2.57      US  1709076735
# 12            10.24      SJ  1709076739

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              west island -12.1568   96.8225     28.77        70          94
# 1           puerto natales -51.7236  -72.4875     12.11        74         100
# 2        port-aux-francais -49.3500   70.2167      8.66        96          99
# 5                 hermanus -34.4187   19.2345     18.78        73           0
# 6               bairnsdale -37.8333  147.6167     27.25        61          17
#
#          Wind Speed Country        Date
# City_ID
# 0              8.27      CC  1709076724
# 1              4.25      CL  1709076725
# 2             11.19      TF  1709076726
# 5              8.24      ZA  1709076730
# 6              0.45      AU  1709076731

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,270),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.8411001338486664

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,295),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.5372385600793336

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.3523197945098256

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.28974812025439

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.28248248182514285

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.15702323046857855

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,8),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.008952355164731349

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.2238836066501698

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
